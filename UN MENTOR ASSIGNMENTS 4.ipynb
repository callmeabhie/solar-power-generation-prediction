# %% [markdown]
# # PANDAS ASSIGNMENTS

# %% [markdown]
# # import pandas and numpy with their aliases

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Create a variable a = pd.Series([100,200,300,400])

# %%
a = pd.Series([100, 200, 300, 400])

# %% [markdown]
# # Print a, and data type

# %%
print(a)
print(type(a))
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64
# <class 'pandas.core.series.Series'>

# %% [markdown]
# # Using indexing access the element 300 from the series a.

# %%
print(a.iloc[2])
# Out:
# 300

# %% [markdown]
# # What are the values of index for series a?

# %%
print(a.index)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# # Change the index to ['c', 'a', 'b', 'd']

# %%
a.index = ['c', 'a', 'b', 'd']

# %% [markdown]
# # Access the value in the series with index 'd'

# %%
print(a['d'])
# Out:
# 400

# %% [markdown]
# # Sort the values wrt to the index and print it

# %%
print(a.sort_index())
# Out:
# a    200
# b    300
# c    100
# d    400
# dtype: int64

# %% [markdown]
# # Create a new Pandas Series b having index as 'e', 'f', and 'g' and value 800,450,100 and print it

# %%
b = pd.Series([800, 450, 100], index=['e', 'f', 'g'])
print(b)
# Out:
# e    800
# f    450
# g    100
# dtype: int64

# %% [markdown]
# # Append b series at the end of the series

# %%
a = pd.concat([a, b])

# %% [markdown]
# # print a again after appending b into it

# %%
b = pd.Series([800, 450, 100], index=['e', 'f', 'g'])
a = pd.concat([a, b])
print(a)
# Out:
# c    100
# a    200
# b    300
# d    400
# e    800
# f    450
# g    100
# e    800
# f    450
# g    100
# dtype: int64

# %% [markdown]
# # Sort the values in descending order of a and print the index of the sorted series

# %%
sorted_a = a.sort_values(ascending=False)
print(sorted_a.index)
# Out:
# Index(['e', 'e', 'f', 'f', 'd', 'b', 'a', 'c', 'g', 'g'], dtype='object')

# %% [markdown]
# # Pandas DataFrame
#
# # Part 1
#
# # Create a pandas dataframe df from the series 'a' that we used in the last section, print the dataframe

# %%
df = a.to_frame()
print(df)
# Out:
#      0
# c  100
# a  200
# b  300
# d  400
# e  800
# f  450
# g  100
# e  800
# f  450
# g  100

# %% [markdown]
# # What is the shape of the datafarme
# # (also, what does it imply?)

# %%
print(df.shape)
print("Shape means (rows, columns).")
# Out:
# (10, 1)
# Shape means (rows, columns).

# %% [markdown]
# # Hey! remember shape (7,1) implies dataframe has 7 rows and 1 column.
#
# # What is the index of the dataframe, is it same as the series 'a'

# %%
print(df.index)
print(df.index.equals(a.index))
# Out:
# Index(['c', 'a', 'b', 'd', 'e', 'f', 'g', 'e', 'f', 'g'], dtype='object')
# True

# %% [markdown]
# # print the head and tail of the dataframe.
# # Additional - (what does head and tali represent?)

# %%
print(df.head())
print(df.tail())
# Out:
#      0
# c  100
# a  200
# b  300
# d  400
# e  800
#      0
# f  450
# g  100
# e  800
# f  450
# g  100

# %% [markdown]
# # Rename the column of the dataframes as 'points'

# %%
df.columns = ['points']
print(df)
# Out:
#    points
# c     100
# a     200
# b     300
# d     400
# e     800
# f     450
# g     100
# e     800
# f     450
# g     100

# %% [markdown]
# # Create another Series 'fruits', which contains random names of fruits from ['orange','mango','apple']. The series should contain 7 elements, randomly selected from ['orange','mango','apple]

# %%
fruits_array = np.random.choice(['orange', 'mango', 'apple'], size=7)

# %% [markdown]
# # Create series fruits out of fruits array

# %%
 #fruits = pd.Series(fruits_array)

# %% [markdown]
# # Change the index of fruits to the index of dataframe df

# %%
fruits = pd.Series(fruits_array, index=df.index[:7])

# %% [markdown]
# # Add this fruits series as a new column to the dataframe df

# %%
df['fruits'] = fruits
print(df.head())
# Out:
#    points fruits
# c     100  apple
# a     200  mango
# b     300  mango
# d     400  mango
# e     800  apple

# %% [markdown]
# # Pandas Concatenation
# # Create a dataframe d1 where the cols are 'city' : ['Chandigarh', 'Delhi', 'Kanpur', 'Chennai', 'Manali' ] and 'Temperature' : [15, 22, 20, 26,-2]

# %%
d1 = pd.DataFrame({'city': ['Chandigarh', 'Delhi', 'Kanpur', 'Chennai', 'Manali'], 'Temperature': [15, 22, 20, 26, -2]})

# %% [markdown]
# # Print(d1)

# %%
print(d1)
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20
# 3     Chennai           26
# 4      Manali           -2

# %% [markdown]
# # What is the shape of d1

# %%
print(d1.shape)
# Out:
# (5, 2)

# %% [markdown]
# # Set city= d1['city']

# %%
city = d1['city']

# %% [markdown]
# # Print city
# # What is the type of city

# %%
print(city)
print(type(city))
# Out:
# 0    Chandigarh
# 1         Delhi
# 2        Kanpur
# 3       Chennai
# 4        Manali
# Name: city, dtype: object
# <class 'pandas.core.series.Series'>

# %% [markdown]
# # Create another datafeame 'd2' where the columns are 'city' - ['Bengalaru','Coimbatore','Srirangam','Pondicherry'] 'Temperature' - [24,35,36,39]

# %%
d2 = pd.DataFrame({'city': ['Bengalaru', 'Coimbatore', 'Srirangam', 'Pondicherry'], 'Temperature': [24, 35, 36, 39]})

# %% [markdown]
# # Print the shape of this dataframe

# %%
print(d2.shape)
# Out:
# (4, 2)

# %% [markdown]
# # merge the two dataframe together,save it in a new dataframe names 'd3'

# %%
d3 = pd.concat([d1, d2], ignore_index=True)
print(d3)
# Out:
#           city  Temperature
# 0   Chandigarh           15
# 1        Delhi           22
# 2       Kanpur           20
# 3      Chennai           26
# 4       Manali           -2
# 5    Bengalaru           24
# 6   Coimbatore           35
# 7    Srirangam           36
# 8  Pondicherry           39

# %% [markdown]
# # Select the part of the dataframe such that it contains cities wherer temp is less then or equal to 20
# # How many cities are there?

# %%
temp_le_20 = d3[d3['Temperature'] <= 20]
print(temp_le_20)
print('Number of cities:', len(temp_le_20))
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 2      Kanpur           20
# 4      Manali           -2
# Number of cities: 3

# %% [markdown]
# # Select the part of the dataframe such that it contains the cities where tempearature greater than or equal to 35

# %%
print(d3[d3['Temperature'] >= 35])
# Out:
#           city  Temperature
# 6   Coimbatore           35
# 7    Srirangam           36
# 8  Pondicherry           39

# %% [markdown]
# # Applying functions to columns and creating new columns
#
# # We need to create another column in d3, which contains a boolean value for each city to indicate whether it's a union territory or not.
#
# # . HINT: Chandigarh, Pondicherry and Delhi are only 3 union territories here.

# %%
def is_ut(x):
    return x in ['Chandigarh', 'Pondicherry', 'Delhi']

d3['is_ut'] = d3['city'].apply(is_ut)

# %%
print(d3)
# Out:
#           city  Temperature  is_ut
# 0   Chandigarh           15   True
# 1        Delhi           22   True
# 2       Kanpur           20  False
# 3      Chennai           26  False
# 4       Manali           -2  False
# 5    Bengalaru           24  False
# 6   Coimbatore           35  False
# 7    Srirangam           36  False
# 8  Pondicherry           39   True

# %% [markdown]
# # The temperatures mentioned in 'Temperature' column are mentioned in Celsius, we need another column which contains the same in Fahrenheit.
#
# # HINT -
#
# # . Define a function c_to_f which takes input temp in celsius and returns a value with temperature in Fahrenheit.
# # . To check: c_to_f(10) should return 50.

# %%
def c_to_f(temp):
    return (temp * 9/5) + 32

# %%
print(c_to_f(10))
# Out:
# 50.0

# %%
# apply function c_to_f to d3 to create a column 'temp_farenhiet'
print(d3.columns)
d3['temp_farenhiet'] = d3['Temperature'].apply(c_to_f)
# Out:
# Index(['city', 'Temperature', 'is_ut'], dtype='object')

# %% [markdown]
# # Indexing and selecting rows in DataFrame
#
# # Select subset of the dataframe d1 such that it contains the cities which are union territories.

# %%
print(d1[d1['city'].isin(['Chandigarh', 'Delhi', 'Pondicherry'])])
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22

# %% [markdown]
# # Select a subset of the dataframe d1 such that it contains the cities which only hav temperature above 90 Farenhiet.

# %%
print(d1[c_to_f(d1['Temperature']) > 90])
# Out:
# Empty DataFrame
# Columns: [city, Temperature]
# Index: []

# %% [markdown]
# # Select only the first three rows of the dataframe d1

# %%
print(d1.iloc[:3])
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20

# %% [markdown]
# # Select all the rows and last two columns in the dataframe

# %%
print(d1.iloc[:, -2:])
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20
# 3     Chennai           26
# 4      Manali           -2

# %% [markdown]
# # Groupby

# %%
# Create a dataframe using dictionary of your choice
data = {
    'name': ['Abhi', 'Rahul', 'Arun'],
    'age': [22, 23, 21],
    'city': ['Kerala', 'Delhi', 'Mumbai']
}

df = pd.DataFrame(data)

# %%
# Use Groupby of single column with aggregate sum()
df.groupby('city').sum()
# Out:
#          name  age
# city
# Delhi   Rahul   23
# Kerala   Abhi   22
# Mumbai   Arun   21

# %%
# Use Groupby of single column with aggregate count()
df.groupby('city').count()
# Out:
#         name  age
# city
# Delhi      1    1
# Kerala     1    1
# Mumbai     1    1

# %%
# Use Groupby of single column with aggregate min() and max()
df.groupby('city').agg(['min', 'max'])
# Out:
#          name        age
#           min    max min max
# city
# Delhi   Rahul  Rahul  23  23
# Kerala   Abhi   Abhi  22  22
# Mumbai   Arun   Arun  21  21

# %%
# Use Groupby of any 2 columns with aggregate mean()
df.groupby(['city', 'name']).mean(numeric_only=True)
# Out:
#                age
# city   name
# Delhi  Rahul  23.0
# Kerala Abhi   22.0
# Mumbai Arun   21.0

# %%
# Use Groupby of any 2 columns with aggregate min() and max()
df.groupby(['city', 'name']).agg(['min', 'max'])
# Out:
#              age
#              min max
# city   name
# Delhi  Rahul  23  23
# Kerala Abhi   22  22
# Mumbai Arun   21  21

# %% [markdown]
# # Data Range
#
# # Create a pandas daterange where starting date is 1st of January,2020 and end date is 1st of April 2021, store it in a new variable named 'a'

# %%
a = pd.date_range(start='2020-01-01', end='2021-04-01')

# %% [markdown]
# # Print a

# %%
print(a)
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2021-03-23', '2021-03-24', '2021-03-25', '2021-03-26',
#                '2021-03-27', '2021-03-28', '2021-03-29', '2021-03-30',
#                '2021-03-31', '2021-04-01'],
#               dtype='datetime64[ns]', length=457, freq='D')

# %% [markdown]
# # What is the len of a?

# %%
print(len(a))
# Out:
# 457

# %% [markdown]
# # What is the type of a

# %%
print(type(a))
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
